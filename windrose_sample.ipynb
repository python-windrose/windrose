# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from numpy.random import random
from numpy import arange

# %%
from windrose import WindroseAxes

# %% [markdown]
# #Create wind speed and direction variables

# %%
N = 500
ws = random(N)*6
wd = random(N)*360

# %%
df = pd.DataFrame({"speed": ws, "direction": wd})
df
# Out:
#       direction     speed
# 0    144.433610  5.980812
# 1     98.182427  0.572944
# 2     85.571010  5.422509
# 3    223.457227  4.210777
# 4    256.793401  4.591010
# 5     26.782039  5.561764
# 6     92.471171  5.330001
# 7    194.794628  0.106901
# 8    155.209568  5.502563
# 9    195.766258  5.722140
# 10   231.297666  4.616848
# 11    80.320648  0.580855
# 12    43.350211  1.658057
# 13    43.416473  5.939761
# 14   134.033616  4.213260
# 15    55.640122  4.376362
# 16    33.161502  1.271678
# 17   173.824598  3.863048
# 18   176.131526  2.564584
# 19   258.108208  5.965748
# 20    21.169616  3.346967
# 21   188.234887  4.434370
# 22    48.840147  4.921423
# 23   221.533981  1.086852
# 24   205.974827  3.605391
# 25   158.605020  4.904052
# 26   251.750883  1.173759
# 27    72.369483  3.262447
# 28   164.987489  4.900633
# 29    92.746916  0.708690
# ..          ...       ...
# 470  184.581078  5.702234
# 471   40.961270  0.372954
# 472  158.132910  1.854211
# 473  150.506114  3.990058
# 474  283.414044  4.212575
# 475  292.971789  1.610411
# 476  157.979311  0.190438
# 477   68.248734  3.118565
# 478   77.266499  3.118051
# 479  264.880536  5.272192
# 480   52.300924  1.261686
# 481  333.442069  2.559750
# 482  200.406506  5.562195
# 483  276.092158  0.752443
# 484  154.744022  4.539117
# 485   17.430361  0.885836
# 486  124.022796  2.435767
# 487   92.123096  3.796702
# 488  109.493679  1.639691
# 489   54.297422  0.409523
# 490  271.033743  2.803588
# 491   18.715572  1.279641
# 492  353.502049  3.891606
# 493    6.651876  5.640791
# 494  101.963429  2.598810
# 495  142.051515  4.878708
# 496  174.650838  4.125069
# 497  213.835055  3.590075
# 498  143.490215  2.541151
# 499  219.879328  0.517308
#
# [500 rows x 2 columns]

# %%
def new_axes():
    fig = plt.figure(figsize=(8, 8), dpi=80, facecolor='w', edgecolor='w')
    rect = [0.1, 0.1, 0.8, 0.8]
    ax = WindroseAxes(fig, rect, axisbg='w')
    fig.add_axes(ax)
    return ax

def set_legend(ax):
    l = ax.legend(borderaxespad=-0.10)
    plt.setp(l.get_texts(), fontsize=8)

# %% [markdown]
# #windrose like a stacked histogram with normed (displayed in percent) results

# %%
ax = new_axes()
ax.bar(df.direction, df.speed, normed=True, opening=0.8, edgecolor='white')
set_legend(ax)

# %% [markdown]
# #Another stacked histogram representation, not normed, with bins limits

# %%
ax = new_axes()
ax.box(df.direction, df.speed, bins=arange(0,8,1))
set_legend(ax)

# %% [markdown]
# #A windrose in filled representation, with a controled colormap

# %%
ax = new_axes()
ax.contourf(df.direction, df.speed, bins=arange(0,8,1), cmap=cm.hot)
set_legend(ax)

# %% [markdown]
# #Same as above, but with contours over each filled region...

# %%
ax = new_axes()
ax.contourf(df.direction, df.speed, bins=arange(0,8,1), cmap=cm.hot)
ax.contour(df.direction, df.speed, bins=arange(0,8,1), colors='black')
set_legend(ax)

# %% [markdown]
# #...or without filled regions

# %%
ax = new_axes()
ax.contour(df.direction, df.speed, bins=arange(0,8,1), cmap=cm.hot, lw=3)
set_legend(ax)
